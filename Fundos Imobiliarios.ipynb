# %% [markdown]
# Listando Fiis

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
import pandas as pd

navegador = webdriver.Chrome()

#BBPO11
navegador.get("https://www.fundsexplorer.com.br/funds/bbpo11")
cotacao_bbpo11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_bbpo11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_bbpo11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_bbpo11 = cotacao_bbpo11.replace("R$","")
cotacao_bbpo11 = cotacao_bbpo11.replace("," , ".")

dividendo_bbpo11 = dividendo_bbpo11.replace("R$","")
dividendo_bbpo11 = dividendo_bbpo11.replace("," , ".")

dy_bbpo11 = dy_bbpo11.replace("," , ".")
dy_bbpo11 = dy_bbpo11.replace("%","")

#BCFF11
navegador.get("https://www.fundsexplorer.com.br/funds/bcff11")
cotacao_bcff11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_bcff11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_bcff11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_bcff11 = cotacao_bcff11.replace("R$","")
cotacao_bcff11 = cotacao_bcff11.replace("," , ".")

dividendo_bcff11 = dividendo_bcff11.replace("R$","")
dividendo_bcff11 = dividendo_bcff11.replace("," , ".")

dy_bcff11 = dy_bcff11.replace("," , ".")
dy_bcff11 = dy_bcff11.replace("%","")

#BTLG11
navegador.get("https://www.fundsexplorer.com.br/funds/btlg11")
cotacao_btlg11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_btlg11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_btlg11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_btlg11 = cotacao_btlg11.replace("R$","")
cotacao_btlg11 = cotacao_btlg11.replace("," , ".")

dividendo_btlg11 = dividendo_btlg11.replace("R$","")
dividendo_btlg11 = dividendo_btlg11.replace("," , ".")

dy_btlg11 = dy_btlg11.replace("," , ".")
dy_btlg11 = dy_btlg11.replace("%","")

#GGRC11
navegador.get("https://www.fundsexplorer.com.br/funds/ggrc11")
cotacao_ggrc11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_ggrc11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_ggrc11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_ggrc11 = cotacao_ggrc11.replace("R$","")
cotacao_ggrc11 = cotacao_ggrc11.replace("," , ".")

dividendo_ggrc11 = dividendo_ggrc11.replace("R$","")
dividendo_ggrc11 = dividendo_ggrc11.replace("," , ".")

dy_ggrc11 = dy_ggrc11.replace("," , ".")
dy_ggrc11 = dy_ggrc11.replace("%","")

#HCTR11
navegador.get("https://www.fundsexplorer.com.br/funds/hctr11")
cotacao_hctr11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_hctr11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_hctr11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_hctr11 = cotacao_hctr11.replace("R$","")
cotacao_hctr11 = cotacao_hctr11.replace("," , ".")

dividendo_hctr11 = dividendo_hctr11.replace("R$","")
dividendo_hctr11 = dividendo_hctr11.replace("," , ".")

dy_hctr11 = dy_hctr11.replace("," , ".")
dy_hctr11 = dy_hctr11.replace("%","")

#IRDM11
navegador.get("https://www.fundsexplorer.com.br/funds/irdm11")
cotacao_irdm11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_irdm11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_irdm11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_irdm11 = cotacao_irdm11.replace("R$","")
cotacao_irdm11 = cotacao_irdm11.replace("," , ".")

dividendo_irdm11 = dividendo_irdm11.replace("R$","")
dividendo_irdm11 = dividendo_irdm11.replace("," , ".")

dy_irdm11 = dy_irdm11.replace("," , ".")
dy_irdm11 = dy_irdm11.replace("%","")

#MXRF11
navegador.get("https://www.fundsexplorer.com.br/funds/mxrf11")
cotacao_mxrf11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_mxrf11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_mxrf11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_mxrf11 = cotacao_mxrf11.replace("R$","")
cotacao_mxrf11 = cotacao_mxrf11.replace("," , ".")

dividendo_mxrf11 = dividendo_mxrf11.replace("R$","")
dividendo_mxrf11 = dividendo_mxrf11.replace("," , ".")

dy_mxrf11 = dy_mxrf11.replace("," , ".")
dy_mxrf11 = dy_mxrf11.replace("%","")

#RBVA11
navegador.get("https://www.fundsexplorer.com.br/funds/rbva11")
cotacao_rbva11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_rbva11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_rbva11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_rbva11 = cotacao_rbva11.replace("R$","")
cotacao_rbva11 = cotacao_rbva11.replace("," , ".")

dividendo_rbva11 = dividendo_rbva11.replace("R$","")
dividendo_rbva11 = dividendo_rbva11.replace("," , ".")

dy_rbva11 = dy_rbva11.replace("," , ".")
dy_rbva11 = dy_rbva11.replace("%","")

#VINO11
navegador.get("https://www.fundsexplorer.com.br/funds/vino11")
cotacao_vino11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_vino11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_vino11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_vino11 = cotacao_vino11.replace("R$","")
cotacao_vino11 = cotacao_vino11.replace("," , ".")

dividendo_vino11 = dividendo_vino11.replace("R$","")
dividendo_vino11 = dividendo_vino11.replace("," , ".")

dy_vino11 = dy_vino11.replace("," , ".")
dy_vino11 = dy_vino11.replace("%","")

#VRTA11
navegador.get("https://www.fundsexplorer.com.br/funds/vrta11")
cotacao_vrta11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_vrta11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_vrta11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_vrta11 = cotacao_vrta11.replace("R$","")
cotacao_vrta11 = cotacao_vrta11.replace("," , ".")

dividendo_vrta11 = dividendo_vrta11.replace("R$","")
dividendo_vrta11 = dividendo_vrta11.replace("," , ".")

dy_vrta11 = dy_vrta11.replace("," , ".")
dy_vrta11 = dy_vrta11.replace("%","")

#XPML11
navegador.get("https://www.fundsexplorer.com.br/funds/xpml11")
cotacao_xpml11 = navegador.find_element(By.XPATH, '//*[@id="stock-price"]/span[1]').text
dividendo_xpml11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[2]/span[2]').text
dy_xpml11 = navegador.find_element(By.XPATH, '//*[@id="main-indicators-carousel"]/div/div/div[3]/span[2]').text

cotacao_xpml11 = cotacao_xpml11.replace("R$","")
cotacao_xpml11 = cotacao_xpml11.replace("," , ".")

dividendo_xpml11 = dividendo_xpml11.replace("R$","")
dividendo_xpml11 = dividendo_xpml11.replace("," , ".")

dy_xpml11 = dy_xpml11.replace("," , ".")
dy_xpml11 = dy_xpml11.replace("%","")

tabela = pd.read_excel("Fundos Imobiliarios.xlsx")

tabela.loc[tabela["Ativo"] == "BBPO11", "Cotação"] = float(cotacao_bbpo11)
tabela.loc[tabela["Ativo"] == "BBPO11", "DY"] = float(dy_bbpo11)
tabela.loc[tabela["Ativo"] == "BBPO11", "Ultimo Rendimento"] = float(dividendo_bbpo11)

tabela.loc[tabela["Ativo"] == "BCFF11", "Cotação"] = float(cotacao_bcff11)
tabela.loc[tabela["Ativo"] == "BCFF11", "DY"] = float(dy_bcff11)
tabela.loc[tabela["Ativo"] == "BCFF11", "Ultimo Rendimento"] = float(dividendo_bcff11)

tabela.loc[tabela["Ativo"] == "BTLG11", "Cotação"] = float(cotacao_btlg11)
tabela.loc[tabela["Ativo"] == "BTLG11", "DY"] = float(dy_btlg11)
tabela.loc[tabela["Ativo"] == "BTLG11", "Ultimo Rendimento"] = float(dividendo_btlg11)

tabela.loc[tabela["Ativo"] == "GGRC11", "Cotação"] = float(cotacao_ggrc11)
tabela.loc[tabela["Ativo"] == "GGRC11", "DY"] = float(dy_ggrc11)
tabela.loc[tabela["Ativo"] == "GGRC11", "Ultimo Rendimento"] = float(dividendo_ggrc11)

tabela.loc[tabela["Ativo"] == "HCTR11", "Cotação"] = float(cotacao_hctr11)
tabela.loc[tabela["Ativo"] == "HCTR11", "DY"] = float(dy_hctr11)
tabela.loc[tabela["Ativo"] == "HCTR11", "Ultimo Rendimento"] = float(dividendo_hctr11)

tabela.loc[tabela["Ativo"] == "IRDM11", "Cotação"] = float(cotacao_irdm11)
tabela.loc[tabela["Ativo"] == "IRDM11", "DY"] = float(dy_irdm11)
tabela.loc[tabela["Ativo"] == "IRDM11", "Ultimo Rendimento"] = float(dividendo_irdm11)

tabela.loc[tabela["Ativo"] == "MXRF11", "Cotação"] = float(cotacao_mxrf11)
tabela.loc[tabela["Ativo"] == "MXRF11", "DY"] = float(dy_mxrf11)
tabela.loc[tabela["Ativo"] == "MXRF11", "Ultimo Rendimento"] = float(dividendo_mxrf11)

tabela.loc[tabela["Ativo"] == "RBVA11", "Cotação"] = float(cotacao_rbva11)
tabela.loc[tabela["Ativo"] == "RBVA11", "DY"] = float(dy_rbva11)
tabela.loc[tabela["Ativo"] == "RBVA11", "Ultimo Rendimento"] = float(dividendo_rbva11)

tabela.loc[tabela["Ativo"] == "VINO11", "Cotação"] = float(cotacao_vino11)
tabela.loc[tabela["Ativo"] == "VINO11", "DY"] = float(dy_vino11)
tabela.loc[tabela["Ativo"] == "VINO11", "Ultimo Rendimento"] = float(dividendo_vino11)

tabela.loc[tabela["Ativo"] == "VRTA11", "Cotação"] = float(cotacao_vrta11)
tabela.loc[tabela["Ativo"] == "VRTA11", "DY"] = float(dy_vrta11)
tabela.loc[tabela["Ativo"] == "VRTA11", "Ultimo Rendimento"] = float(dividendo_vrta11)

tabela.loc[tabela["Ativo"] == "XPML11", "Cotação"] = float(cotacao_vrta11)
tabela.loc[tabela["Ativo"] == "XPML11", "DY"] = float(dy_vrta11)
tabela.loc[tabela["Ativo"] == "XPML11", "Ultimo Rendimento"] = float(dividendo_vrta11)

tabela["Cotação"] = tabela["Cotação"].map("R${:.2f}".format)
tabela["Ultimo Rendimento"] = tabela["Ultimo Rendimento"].map("R${:.2f}".format)
tabela["DY"] = tabela["DY"].map("{:.2f}%".format)
navegador.quit()

tabela.to_excel("Fundos Imobiliarios.xlsx", index=False)
